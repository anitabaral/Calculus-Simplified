# %%
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 691.6 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 996.4 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 744.5 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Calculus
# In this article, I will discuss basic calculus concepts and use graphs to visualize them.
# Topics covered in this part will be as follows:
#
# - Slope, Derivative
# - Derivative of a curve (cosine wave)
# - Maximum and Minimum of a curve, Inflection point

# %% [markdown]
# #### Slope
# Measure of the steepness of a line. It can be incline, decline, or flat.
# It is typically calculated using the formula:
# $$ slope = \frac{rise}{run} \text{ or } \frac{up}{across} $$
# This formula captures how much the line goes up or down (rise) for a horizontal distance (run).
#
# Let's break it down:
#
# **Incline (Positive Slope)**: When a line slants upwards from left to right, it has a positive slope. This means that as you move along the line to the right (run), it goes up (rise). The greater the rise for a given run, the steeper the line and the greater the slope (slope > 0).
#
# **Decline (Negative Slope)**: A line that slants downwards from left to right has a negative slope. Here, as you move to the right (run), the line goes down (negative rise). A steeper downward slope will have a larger negative value, indicating a sharper decline (slope < 0).
#
# **Flat (Zero Slope)**: A horizontal line has a zero slope. This means there is no vertical change as you move along the line; the rise is zero. No matter how far you run horizontally, if there's no up or down movement, the slope is 0 (slope = 0).
#
# Example:
# > Speed is the slope of distance to time, i.e. speed = riserun or distancetime
#
# > Acceleration is the slope of speed to time, i.e. acceleration = upacross or speedtime

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# Time array
time = np.linspace(0, 10, 100)

# Calculating distance and slope for positive case
distance_positive = time * 10
slope_positive = np.full(time.shape, 10)  

# Creating a figure with two subplots
plt.figure(figsize=(12, 4))

# Plotting Distance vs Time with Positive Slope
ax1 = plt.subplot(1, 2, 1)
sns.lineplot(x=time, y=distance_positive, ax=ax1)
ax1.set(xlabel='Time (seconds)', ylabel='Distance (miles)', title='Distance vs Time d(t)')

# Plotting Slope (Speed) vs Time with Positive Slope
ax2 = plt.subplot(1, 2, 2)
sns.lineplot(x=time, y=slope_positive, ax=ax2, color='green')
ax2.set(xlabel='Time (seconds)', ylabel='slope/speed', title='Positive Slope (Moving Away) s(t)')

aplt.tight_layout()

# Saving the figure to a file
plt.savefig("distance_time_graph_positive_slope.jpg") 
# plt.close() # Closing the plot to free up resources

# %% [markdown]
# #### Visualization of positive, negative, and zero slopes of a curve.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# Time array
time = np.linspace(0, 10, 100)

# Calculating distance and slope for positive case
distance_positive = time * 10
slope_positive = np.full(time.shape, 10)  

# Creating a figure with two subplots
plt.figure(figsize=(12, 4))

# Plotting Distance vs Time with Positive Slope
ax1 = plt.subplot(1, 2, 1)
sns.lineplot(x=time, y=distance_positive, ax=ax1)
ax1.set(xlabel='Time (seconds)', ylabel='Distance (miles)', title='Distance vs Time d(t)')

# Plotting Slope (Speed) vs Time with Positive Slope
ax2 = plt.subplot(1, 2, 2)
sns.lineplot(x=time, y=slope_positive, ax=ax2, color='green')
ax2.set(xlabel='Time (seconds)', ylabel='slope/speed', title='Positive Slope (Moving Away) s(t)')

aplt.tight_layout()

# Saving the figure to a file
plt.savefig("distance_time_graph_positive_slope.jpg") 
# plt.close() # Closing the plot to free up resources

# %% [markdown]
# Graph 1 visualizes the function_1 d(t), which provides the distance covered at every time step.
# Graph 2 visualizes the rate of change of function_1 d(t), which is known as the function_2 slope/speed. Here, as time increases, distance also increases with a constant value of 10 at every time step; hence, it has a slope of 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# Time array
time = np.linspace(0, 10, 100)

# Calculating distance and slope for positive case
distance_positive = 100 - time * 10
slope_positive = np.full(time.shape, -10)  

# Creating a figure with two subplots
plt.figure(figsize=(12, 4))

# Plotting Distance vs Time with Positive Slope
ax1 = plt.subplot(1, 2, 1)
sns.lineplot(x=time, y=distance_positive, ax=ax1)
ax1.set(xlabel='Time (seconds)', ylabel='Distance (miles)', title='Distance vs Time d(t)')

# Plotting Slope (Speed) vs Time with Positive Slope
ax2 = plt.subplot(1, 2, 2)
sns.lineplot(x=time, y=slope_positive, ax=ax2, color='green')
ax2.set(xlabel='Time (seconds)', ylabel='slope/speed', title='Negative Slope (Moving Towards) s(t)')

plt.tight_layout()

# Saving the figure to a file
plt.savefig("distance_time_graph_negative_slope.jpg") 
# plt.close() # Closing the plot to free up resources

# %% [markdown]
# Here, as time increases, the distance covered decreases, with a constant value of 10; hence, it has a slope of -10.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Setting seaborn style for better aesthetics
sns.set()

# Time array
time = np.linspace(0, 10, 100)

# Calculating distance and slope for positive case
distance_positive = 50
slope_positive = np.full(time.shape, 0)  

# Creating a figure with two subplots
plt.figure(figsize=(12, 4))

# Plotting Distance vs Time with Positive Slope
ax1 = plt.subplot(1, 2, 1)
sns.lineplot(x=time, y=distance_positive, ax=ax1)
ax1.set(xlabel='Time (seconds)', ylabel='Distance (miles)', title='Distance vs Time d(t)')

# Plotting Slope (Speed) vs Time with Positive Slope
ax2 = plt.subplot(1, 2, 2)
sns.lineplot(x=time, y=slope_positive, ax=ax2, color='green')
ax2.set(xlabel='Time (seconds)', ylabel='slope/speed', title='Zero Slope (Halt) s(t)')

# Adjusting layout for better visibility
plt.tight_layout()

# Saving the figure to a file
plt.savefig("distance_time_graph_zero_slope.jpg") 
# plt.close() # Closing the plot to free up resources

# %% [markdown]
# Here, as time increases, the distance covered remains constant, indicating no change in slope; hence, it has a slope of 0.

# %% [markdown]
# #### Derivative
#
# The derivative of a function at a given point represents the rate of change of the function at that point. It gives the slope of the tangent line to the graph of the function at that point. The slope, on the other hand, refers to the steepness of a line and is a measure of how much the line rises or falls for a given horizontal change.
#
# Derivative is used to visualize how a function changes at each point.
#
# Relationship between Slope and Derivative
# 1. Constant Functions: For a linear function (a straight line), the derivative is constant and equal to the slope of the line.
#
# 2. Non-Linear Functions: For curves (non-linear functions), the derivative varies at different points. The derivative at any point gives the slope of the tangent line to the curve at that point.
#
# In the upcoming part of the article, we will be discussing the derivative of a function as now we will be looking at instantaneous change and non-linear functions.
#
# ##### Derivative of a non-linear function (Sine Wave)
#
# Derivative of a sine wave is represented by the curve that illustrates the slope of the tangent line to sine wave at every point. Cosine wave is able to represent the slope of sine wave at all instants and hence it is its derivative.
#
# Let’s view at certain angles
# 1. Angle = 0
#
# > The tangent line at that point in sine curve has a slope of 1, as provided in the cosine curve
#
# 3. Angle = π/2
#
# > The tangent line at that point in sine curve has a slope of 0, as provided in the cosine curve
#
# Starting at 0 degrees angle, the sine curve inclination keeps on decreasing until it reaches 90 degrees angle where it remains constant, which can be visualized by the declining curve from 0 to 90 degrees in cosine curve and finally reaching zero.
#
# Similarly, the inclination, declination and flatness at every point of sine curve is represented by cosine curve which is it’s derivative.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Setting up the figure
plt.figure(figsize=(12, 6))

# Sine Curve in Degrees
plt.subplot(1, 2, 1)
x_deg = np.linspace(0, 360, 361)  # X-axis in degrees
x_rad = np.deg2rad(x_deg)  # Convert degrees to radians for the sine function
plt.plot(x_deg, np.sin(x_rad))
plt.axhline(0, color='green', linewidth=0.8)  # Line through the zero axis
plt.xlabel('Angle (Degree)')
plt.ylabel('sin(x)')
plt.title('Sine Curve')
# plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(format_func))  # Formatting x-axis with pi in degrees
plt.grid(True)  # Show the grid (axes)

# Cosine Curve in Degrees
plt.subplot(1, 2, 2)
plt.plot(x_deg, np.cos(x_rad))
plt.axhline(0, color='green', linewidth=0.8)  # Line through the zero axis
plt.xlabel('Angle (Degree)')
plt.ylabel('cos(x)')
plt.title('Derivative Of Sine (Cosine Curve)')
plt.grid(True)  # Show the grid (axes)

plt.tight_layout()
plt.savefig("derivative_sine.jpg") 
plt.show()
plt.close() # Closing the plot to free up resources

# %% [markdown]
# #### Maximum and Minimum of a curve, Inflection point
#
# At maximum point of a curve:
# * First Derivative  = 0
# * Second Derivative < 0
# * The curve is bending downwards
# * Concave Curve
#
# At maximum point of a curve:
# * First Derivative  = 0
# * Second Derivative > 0
# * The curve is bending upwards
# * Convex Curve
#
# Inflection point:
# * Second derivative = 0
# * Curve changes from concave to convex or vice versa

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Setting seaborn style for better aesthetics
sns.set()

# Setting up the figure
plt.figure(figsize=(12, 4))

# Sine Curve in Degrees
plt.subplot(1, 3, 1)
x_deg = np.linspace(0, 360, 201)  # X-axis in degrees
x_rad = np.deg2rad(x_deg)  # Convert degrees to radians for the sine function
sns.lineplot(x=x_deg, y=np.sin(x_rad))
plt.axhline(0, color='green', linewidth=0.8)  # Line through the zero axis
plt.xlabel('Angle [degrees]')
plt.ylabel('sin(x)')
plt.title('Sine Curve')
plt.grid(True)  # Show the grid (axes)

# Cosine Curve in Degrees
plt.subplot(1, 3, 2)
sns.lineplot(x=x_deg, y=np.cos(x_rad))
plt.axhline(0, color='green', linewidth=0.8)  # Line through the zero axis
plt.xlabel('Angle [degrees]')
plt.ylabel('cos(x)')
plt.title('Derivative of Sine Curve')
plt.grid(True)  # Show the grid (axes)

# Negative Sine Curve in Degrees
plt.subplot(1, 3, 3)
sns.lineplot(x=x_deg, y=-np.sin(x_rad))
plt.axhline(0, color='green', linewidth=0.8)  # Line through the zero axis
plt.xlabel('Angle [degrees]')
plt.ylabel('-sin(x)')
plt.title('Second Derivative of Sine Curve')
plt.grid(True)  # Show the grid (axes)

plt.tight_layout()
plt.savefig("maximum_minimum.jpg") 
plt.show()
plt.close() # Closing the plot to free up resources

# %% [markdown]
# In the above graph,
# Maximum point is at 90 degrees angle
# * First derivative at that point = 0
# * Second derivative < 0
#
# Minimum point is at 270 degrees angle
# * First derivative at that point = 0
# * Second derivative > 0
#
# Inflection point is at  180 degrees angle
# * Second derivative = 0
